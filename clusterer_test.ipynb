# %%
from clusterer import Clusterer, ClusterType
clusterer = Clusterer(n_components=0.8)

# %%
clusterer.X_test
# Out:
#                            load_forecast  coal_power_available  \
# DELIVERY_START
# 2023-04-01 22:00:00+00:00      -0.340926              1.418625
# 2023-04-01 23:00:00+00:00      -0.501614              1.418625
# 2023-04-02 00:00:00+00:00      -0.576200              1.418625
# 2023-04-02 01:00:00+00:00      -0.804321              1.418625
# 2023-04-02 02:00:00+00:00      -0.957022              1.418625
# ...                                  ...                   ...
# 2023-10-24 17:00:00+00:00       0.018720             -0.911772
# 2023-10-24 18:00:00+00:00       0.363410             -0.911772
# 2023-10-24 19:00:00+00:00       0.102315             -0.911772
# 2023-10-24 20:00:00+00:00      -0.251479             -0.911772
# 2023-10-24 21:00:00+00:00      -0.288353             -0.911772
#
#                            gas_power_available  nuclear_power_available  \
# DELIVERY_START
# 2023-04-01 22:00:00+00:00            -0.904700                  0.10995
# ...

# %%
o
